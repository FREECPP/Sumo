# %%
import traci

# %%
# Verbinde mit der laufenden SUMO-Instanz
traci.connect(port=8873)

# Test: Liste aller Fahrzeuge ausgeben
vehicles = traci.vehicle.getIDList()
print("Fahrzeuge in der Simulation:", vehicles)

# Verbindung schließen, wenn fertig
traci.close()
# Out:
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
#  Retrying in 1 seconds
# Could not connect to TraCI server at localhost:8873 [Errno 61] Connection refused
# ...
